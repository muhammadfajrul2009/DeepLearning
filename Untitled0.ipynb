# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadfajrul2009/DeepLearning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mkdir -p /content/deeplearning

# %%
# !unzip /content/drive/MyDrive/deeplearning/archive.zip -d /content/arcihve
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/arcihve/natural_images/cat/cat_0204.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0205.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0206.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0207.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0208.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0209.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0210.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0211.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0212.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0213.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0214.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0215.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0216.jpg
#   inflating: /content/arcihve/natural_images/cat/cat_0217.jpg
# ...

# %%
import numpy as np 
import pandas as pd


import os
for dirname, _, filenames in os.walk('/content/arcihve/natural_images'):
    for filename in filenames:
        (os.path.join(dirname, filename))

# %%
labels = os.listdir('../content/arcihve/natural_images/')
print(labels)
# Out:
# ['cat', 'fruit', 'car', 'airplane', 'person', 'dog', 'flower', 'motorbike']

# %%
from IPython.display import Image, display
num = []
for label in labels:
    path = '../content/arcihve/natural_images/{0}/'.format(label)
    folder_data = os.listdir(path)
    k = 0
    print('\n', label.upper())
    for image_path in folder_data:
        if k < 5:
            display(Image(path+image_path))
        k = k+1
    num.append(k)
    print('there are ', k,' images in ', label, 'class')
# Out:
#  CAT
# there are  885  images in  cat class
#
#  FRUIT
# there are  1000  images in  fruit class
#
#  CAR
# there are  968  images in  car class
#
#  AIRPLANE
# there are  727  images in  airplane class
#
#  PERSON
# there are  986  images in  person class
#
#  DOG
# there are  702  images in  dog class
#
#  FLOWER
# there are  843  images in  flower class
#
#  MOTORBIKE
# there are  788  images in  motorbike class

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8,8))
plt.bar(labels, num)
plt.title('NUMBER OF IMAGES CONTAINED IN EACH CLASS')
plt.xlabel('classes')
plt.ylabel('count')
plt.show()

# %%
x_data =[]
y_data = []
import cv2
for label in labels:
    path = '../content/arcihve/natural_images/{0}/'.format(label)
    folder_data = os.listdir(path)
    for image_path in folder_data:
        image = cv2.imread(path+image_path)
        image_resized = cv2.resize(image, (32,32))
        x_data.append(np.array(image_resized))
        y_data.append(label)

# %%
x_data = np.array(x_data)
y_data = np.array(y_data)
print('the shape of X is: ', x_data.shape, 'and that of Y is: ', y_data.shape)
# Out:
# the shape of X is:  (6899, 32, 32, 3) and that of Y is:  (6899,)

# %%
x_data = x_data.astype('float32')/255

# %%
from sklearn.preprocessing import LabelEncoder
y_encoded = LabelEncoder().fit_transform(y_data)
from keras.utils import to_categorical
y_categorical = to_categorical(y_encoded)

# %%
r = np.arange(x_data.shape[0])
np.random.seed(42)
np.random.shuffle(r)
X = x_data[r]
Y = y_categorical[r]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.33)

# %%
from keras import models, layers
model = models.Sequential()
model.add(layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Dropout(rate=0.25))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(8, activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 116/116 [==============================] - 11s 8ms/step - loss: 1.2878 - accuracy: 0.5318 - val_loss: 0.8483 - val_accuracy: 0.6908
# Epoch 2/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.6974 - accuracy: 0.7503 - val_loss: 0.6065 - val_accuracy: 0.7924
# Epoch 3/100
# 116/116 [==============================] - 1s 6ms/step - loss: 0.4999 - accuracy: 0.8177 - val_loss: 0.5702 - val_accuracy: 0.8097
# Epoch 4/100
# 116/116 [==============================] - 1s 6ms/step - loss: 0.3822 - accuracy: 0.8596 - val_loss: 0.3987 - val_accuracy: 0.8508
# Epoch 5/100
# 116/116 [==============================] - 1s 7ms/step - loss: 0.3235 - accuracy: 0.8796 - val_loss: 0.3813 - val_accuracy: 0.8616
# Epoch 6/100
# 116/116 [==============================] - 1s 7ms/step - loss: 0.2987 - accuracy: 0.8942 - val_loss: 0.3757 - val_accuracy: 0.8573
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8,8))
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss/accuracy')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from keras.utils import plot_model
plot_model(model)

# %%
Y_pred = model.predict(X_test)
# Out:
# 72/72 [==============================] - 0s 2ms/step

# %%
Y_test = np.argmax(Y_test, axis = 0)

# %%
from sklearn.metrics import accuracy_score
print('the accuracy obtained on the test set is:', accuracy_score(Y_pred,Y_test))
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-34-3f342b3ac6a7> in <cell line: 2>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print('the accuracy obtained on the test set is:', accuracy_score(Y_pred,Y_test))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     185             params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
#     186
# --> 187             validate_parameter_constraints(
#     188                 parameter_constraints, params, caller_name=func.__qualname__
#     189             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      95                 )
#      96
# ---> 97             raise InvalidParameterError(
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-6ef11f8cb3d6> in <cell line: 2>()
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(Y_test, Y_pred))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2308     """
#    2309
# -> 2310     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2311
#    2312     if labels is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      84     y_pred : array or indicator matrix
#      85     """
# ---> 86     check_consistent_length(y_true, y_pred)
#      87     type_true = type_of_target(y_true, input_name="y_true")
# ...
